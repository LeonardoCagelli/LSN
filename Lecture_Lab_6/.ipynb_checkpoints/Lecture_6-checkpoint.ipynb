# %% [markdown]
# # Lecture 6

# %% [markdown]
# ## Exercise 6.1

# %% [markdown]
# Complete the NSL_simulator code to simulate a 1D Ising model with the Gibbs sampling algorithm (the Metropolis algorithm is already implemented) to sample the Boltzmann's weight $p(\{ s_i \}) = \exp(-\beta H)/Z$. Verify the possibility to restart from a previous spin configuration.
#
# The code already computes the internal energy: $U(N,T) = \langle H \rangle$. Add the calculation of $C(N,T)$, $\chi(N,T)$, $M(N,T,h)$ and compute:
# 1. $U(N,T) = \langle H \rangle_{h=0}$
# 2. $C(N,T) = k_B \beta^2 (\langle H^2 \rangle_{h=0}-\langle H \rangle_{h=0}^2)$
# 3. $\chi(N,T) = \beta \langle (\sum_{i=1,N}s_i)^2 \rangle_{h=0}$
# 4. $M(N,T,h=0.02)= \langle \sum_{i=1,N}s_i \rangle_{h=0.02}$
#
# as a function of $T$ in the range $\left[0.5;2.0\right]$ for a system of $N=50$ spins with $J=1$.
#
# As usual, use data blocking and give an estimate of the statistical uncertainties.

# %% [markdown]
# In Statistical Mechanics the one-dimensional (1D) Ising Model is exactly resoluble. The Hamiltonian for a system of N spins with nearest neighbors interaction is given by (in the following I will assume units such that $\mu_B=1$ and $k_B=1$):
#
# $$
# H =
# -J\sum_{i=1}^N s_i s_{i+1}
# -\frac{h}{2}\sum_{i=1}^N (s_i + s_{i+1})
# $$
#
# where $\{ s_i \}_{i=1,N}$ are spin variables taking values in $\{-1;1\}$, $J>0$ (ferromagnetic model),and with the assumption $s_{N+1} = s_{1}$.
#
# The partition function for $N$ spins, $Z$, can be exactly computed and it turns out to be:
#
# $$
# Z=\sum_{\{ s_i \}} \exp \left( -\beta H\right) = \lambda_1^N + \lambda_2^N
# $$
#
# where
# $\lambda_{1,2} =
# e^{\beta J}
# \cosh (\beta h) \pm \left[ e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J) \right]^{1/2}$,
# and where $\beta=\frac{1}{k_b T} = \frac{1}{T}$.
# Once the partition function has been computed, the Helmholtz free energy is readly obtained as $A = -k_B T \ln Z$. All the thermodynamic quantities of interest can be deduced from $A$ or, equivalently, from $Z$:
#
# - the **Internal Energy** per spin (with $h=0$):
#
# $$
# \frac{U(N,T)}{N} = \frac{\langle H \rangle}{N}
# = \frac{1}{N} \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}
# = -\frac{1}{N}\frac{\partial \ln Z}{\partial \beta}
# \underset{h=0}= -J \tanh (\beta J) \Biggl( \frac{1 + \tanh^{N-2} (\beta J)}{1+\tanh^N (\beta J)} \Biggl)
# $$

# %% [markdown]
# - the **Heat Capacity** (with $h=0$):
#
# $$
# C(N,T) = \frac{\partial U(N,T)}{\partial T}
# = \frac{\partial \beta}{\partial T}\frac{\partial U}{\partial \beta}
# = -k_B\beta^2 \frac{\partial}{\partial \beta} \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z} \right] = \\
# = -k_B\beta^2 \left[ -\sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \sum_{\{ s_i \}} H \exp \left( -\beta H\right)\frac{\partial Z^{-1}}{\partial \beta} \right] = \\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]\frac{1}{Z}\frac{\partial Z}{\partial \beta} \right\} =\\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} - \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]^2 \right\} =
# k_B\beta^2 \left(\langle H^2 \rangle -\langle H \rangle^2 \right)
# $$
#
# $$
# \frac{C(N,T)}{N} = \frac{1}{N}\frac{\partial U(N,T)}{\partial T} =\\
# \underset{h=0}=
# k_B (\beta J)^2 \left\{ 1+\tanh^N (\beta J)+(N-1)\tanh^2 (\beta J)+(N-1)\frac{\tanh^{N-2} (\beta J)}{1+\tanh^N (\beta J)}
# - N \left[ \frac{\tanh (\beta J) + \tanh^{N-1} (\beta J)}{1+\tanh^N (\beta J)} \right]^2 \right\}
# $$

# %% [markdown]
# - The **magnetization** (with $h \not= 0$):
#
# Note that with $h=0$ the magnetization $M(N,T,h=0)=\langle \sum_{i=1,N}s_i \rangle =0$ because in 1D we cannot have a (ferromagnetic) phase transition in absence of an external magnetic field.
#
# $$
# M(N,T,h) = -\frac{\partial A}{\partial h} = k_B T \frac{\partial \ln Z}{\partial h} =
# \frac{1}{\beta} \frac{1}{Z}\frac{\partial}{\partial h}\sum_{\{ s_i \}} \exp \left( -\beta H\right) = \sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z} = \left\langle \sum_{i=1,N}s_i \right\rangle
# $$
#
# The exact formula from $M(N,T,h) = k_B T \dfrac{\partial \ln Z}{\partial h}$ is:
# $$
# \frac{M(N,T,h)}{N}=\frac{e^{\beta J}\; \sinh(\beta h)}{Z} \; \Bigl[\lambda_1^{N-1}\cdot \Bigl(1+\frac{e^{\beta J}\; \cosh(\beta h)}{\sqrt{e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J)}}\Bigr) + \lambda_2^{N-1}\cdot \Bigl(1-\frac{e^{\beta J}\; \cosh(\beta h)}{\sqrt{e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J)}}\Bigr)\Bigr]
# $$

# %% [markdown]
# - The **magnetic susceptibility** (with $h=0$):
#
# $$
# \chi(N,T) = \frac{\partial M}{\partial h} =
# \frac{\partial}{\partial h}\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z} =\\
# = \beta\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right]^2 \frac{\exp \left( -\beta H\right)}{Z}
# -\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z}
# \frac{1}{Z}\frac{\partial Z}{\partial h} =
# \beta \left[ \left\langle \left( \sum_{i=1,N}s_i \right)^2 \right\rangle - \left\langle \sum_{i=1,N}s_i \right\rangle^2 \right] = \\
# \underset{h=0}= \beta \left[ \left\langle \left( \sum_{i=1,N}s_i \right)^2 \right\rangle \right] = \beta e^{2\beta J} \Biggl( \frac{1-\tanh^N (\beta J)}{1+\tanh^N (\beta J)} \Biggl)
# $$

# %% [markdown]
# ### Implementation

# %% [markdown]
# - **Number of Blocks:** 20
# - **Steps per Block:** 10,000
# - **Total Steps:** 200,000
# - **Equilibration Steps:** 20,000

# %%
import numpy as np
import matplotlib.pyplot as plt

def load_data(prop, sim_type):
    v_dat, v_err = [], []
    for temp in v_temp:
        path = 'NSL_SIMULATOR/OUTPUT/' + prop + '_' + sim_type + '_' + temp + '.dat'
        data = np.loadtxt(path)
        v_dat.append(data[-1, 2])
        v_err.append(data[-1, 3])
    return v_dat, v_err

def chi_square(data, true_value, sigma):
    v = []
    chi = 0
    for i in range(len(data)):
        chi += (pow(data[i] - true_value[i], 2) / sigma[i]**2)
        v.append(pow(data[i] - true_value[i], 2) / sigma[i]**2)
    #v = [f"{x:.4f}" for x in v]
    return chi / len(data), v

# %%
v_temp = ['0.500000', '0.750000', '1.000000', '1.250000', '1.500000', '1.750000', '2.000000']
sim_type = ['MRT2', 'GIBBS']
points = 100
T = np.linspace(0.2, 3.0, num=points)
beta = 1 / T
J = 1.0
Ns = 50
h = 0.02

th = np.tanh(J / T)
thN = th**Ns
ch = 1 / th
b = 1 / T
l1 = np.exp(b * J) * np.cosh(b * h) + np.sqrt(np.exp(2 * b * J) * np.cosh(b * h)**2 - 2 * np.sinh(2 * b * J))
l2 = np.exp(b * J) * np.cosh(b * h) - np.sqrt(np.exp(2 * b * J) * np.cosh(b * h)**2 - 2 * np.sinh(2 * b * J))
Z = l1**Ns + l2**Ns

M = (np.exp(b * J) * np.sinh(b * h) * 
    ((l1**(Ns - 1)) * (1 + np.exp(b * J) * np.cosh(b * h) / np.sqrt(np.exp(2 * b * J) * np.cosh(b * h)**2 - 2 * np.sinh(2 * b * J))) + 
     (l2**(Ns - 1)) * (1 - np.exp(b * J) * np.cosh(b * h) / np.sqrt(np.exp(2 * b * J) * np.cosh(b * h)**2 - 2 * np.sinh(2 * b * J)))) / Z)
X = beta * np.exp(2 * beta * J) * (1 - thN) / (1 + thN)
heat = ((beta * J)**2) * (((1 + thN + (Ns - 1) * (th**2) + (Ns - 1) * (ch**2) * thN) / (1 + thN)) - Ns * ((th + ch * thN) / (1 + thN))**2)
e = -J * (th + ch * thN) / (1 + thN)

colors = ['darkblue', 'orchid']
markers = ['v', '^']

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 16))

ax1.plot(T, M, '--', color='black', label='Theoretical Value')
ax2.plot(T, X, '--', color='black', label="Theoretical Value")
ax3.plot(T, e, "--", color='black', label="Theoretical Value")
ax4.plot(T, heat, "--", color='black', label="Theoretical Value")

v_m_mrt2, v_m_mrt2_err = load_data('magnetization', 'MRT2')
v_chi_mrt2, v_chi_mrt2_err = load_data('susceptibility', 'MRT2')
v_te_mrt2, v_te_mrt2_err = load_data('total_energy', 'MRT2')
v_cv_mrt2, v_cv_mrt2_err = load_data('specific_heat', 'MRT2')

v_m_gibbs, v_m_gibbs_err = load_data2('magnetization', 'GIBBS')
v_chi_gibbs, v_chi_gibbs_err = load_data('susceptibility', 'GIBBS')
v_te_gibbs, v_te_gibbs_err = load_data('total_energy', 'GIBBS')
v_cv_gibbs, v_cv_gibbs_err = load_data('specific_heat', 'GIBBS')

v_t = [float(temp) for temp in v_temp]

ax1.errorbar(v_t, v_m_mrt2, yerr=v_m_mrt2_err, fmt=markers[0], color=colors[0], label='MRT2', markersize=10)
ax1.errorbar(v_t, v_m_gibbs, yerr=v_m_gibbs_err, fmt=markers[1], color=colors[1], label='GIBBS', markersize=10)

ax2.errorbar(v_t, v_chi_mrt2, yerr=v_chi_mrt2_err, fmt=markers[0], color=colors[0], label='MRT2', markersize=10)
ax2.errorbar(v_t, v_chi_gibbs, yerr=v_chi_gibbs_err, fmt=markers[1], color=colors[1], label='GIBBS', markersize=10)

ax3.errorbar(v_t, v_te_mrt2, yerr=v_te_mrt2_err, fmt=markers[0], color=colors[0], label='MRT2', markersize=10)
ax3.errorbar(v_t, v_te_gibbs, yerr=v_te_gibbs_err, fmt=markers[1], color=colors[1], label='GIBBS', markersize=10)

ax4.errorbar(v_t, v_cv_mrt2, yerr=v_cv_mrt2_err, fmt=markers[0], color=colors[0], label='MRT2', markersize=10)
ax4.errorbar(v_t, v_cv_gibbs, yerr=v_cv_gibbs_err, fmt=markers[1], color=colors[1], label='GIBBS', markersize=10)

for ax, title, ylabel in zip(
    [ax1, ax2, ax3, ax4],
    ["Magnetization", "Susceptibility", "Total Energy", "Specific Heat"],
    ["Magnetization", "Susceptibility", "Total Energy", "Specific Heat"]
):
    ax.set_title(title, fontsize=16)
    ax.set_xlabel("Temperature", fontsize=12)
    ax.set_ylabel(ylabel, fontsize=12)
    ax.legend(loc='best', fontsize=10)
    ax.grid(True)

plt.show()

# %%
T = np.linspace(0.5, 2, 7)
beta = 1 / T
th = np.tanh(J / T)
thN = th**Ns
ch = 1 / th
b = 1 / T
l1 = np.exp(b * J) * np.cosh(b * h) + np.sqrt(np.exp(2 * b * J) * np.cosh(b * h)**2 - 2 * np.sinh(2 * b * J))
l2 = np.exp(b * J) * np.cosh(b * h) - np.sqrt(np.exp(2 * b * J) * np.cosh(b * h)**2 - 2 * np.sinh(2 * b * J))
Z = l1**Ns + l2**Ns

v_m_true = (np.exp(b * J) * np.sinh(b * h) * 
    ((l1**(Ns - 1)) * (1 + np.exp(b * J) * np.cosh(b * h) / np.sqrt(np.exp(2 * b * J) * np.cosh(b * h)**2 - 2 * np.sinh(2 * b * J))) + 
     (l2**(Ns - 1)) * (1 - np.exp(b * J) * np.cosh(b * h) / np.sqrt(np.exp(2 * b * J) * np.cosh(b * h)**2 - 2 * np.sinh(2 * b * J)))) / Z)
v_chi_true = beta * np.exp(2 * beta * J) * (1 - thN) / (1 + thN)
v_cv_true = ((beta * J)**2) * (((1 + thN + (Ns - 1) * (th**2) + (Ns - 1) * (ch**2) * thN) / (1 + thN)) - Ns * ((th + ch * thN) / (1 + thN))**2)
v_te_true = -J * (th + ch * thN) / (1 + thN)

print("Chi^2 magnetization with Metropolis: ", chi_square(v_m_mrt2, v_m_true, v_m_mrt2_err)[0])
print("Chi^2 susceptibility with Metropolis: ", chi_square(v_chi_mrt2, v_chi_true, v_chi_mrt2_err)[0])
print("Chi^2 total energy with Metropolis: ", chi_square(v_te_mrt2, v_te_true, v_te_mrt2_err)[0])
print("Chi^2 heat capacity with Metropolis: ", chi_square(v_cv_mrt2, v_cv_true, v_cv_mrt2_err)[0])
print("\nChi^2 magnetization with Gibbs: ", chi_square(v_m_gibbs, v_m_true, v_m_gibbs_err)[0])
print("Chi^2 susceptibility with Gibbs: ", chi_square(v_chi_gibbs, v_chi_true, v_chi_gibbs_err)[0])
print("Chi^2 total energy with Gibbs: ", chi_square(v_te_gibbs, v_te_true, v_te_gibbs_err)[0])
print("Chi^2 heat capacity with Gibbs: ", chi_square(v_cv_gibbs, v_cv_true, v_cv_gibbs_err)[0])
# Out:
# Chi^2 magnetization with Metropolis:  0.8621270281923229
# Chi^2 susceptibility with Metropolis:  0.18241510412841028
# Chi^2 total energy with Metropolis:  0.6773074962268332
# Chi^2 heat capacity with Metropolis:  0.26392955101182813
#
# Chi^2 magnetization with Gibbs:  0.42508414983327
# Chi^2 susceptibility with Gibbs:  1.9866808596774068
# Chi^2 total energy with Gibbs:  0.7439190990562162
# Chi^2 heat capacity with Gibbs:  1.0216064305613253

# %%
colors = ['midnightblue', 'mediumblue', 'royalblue', 'skyblue', 'indigo', 'darkviolet', 'violet', 'plum']

x = np.arange(1, len(chi_square(v_m_mrt2, v_m_true, v_m_mrt2_err)[1]) + 1)
v = chi_square(v_m_mrt2, v_m_true, v_m_mrt2_err)[1]


plt.figure(figsize=(18, 6))
plt.suptitle('Chi Square', fontsize=20)
plt.subplot(1, 2, 1)
plt.plot(v_temp, chi_square(v_m_mrt2, v_m_true, v_m_mrt2_err)[1], 'o-', label='Magnetization', color=colors[0])
plt.plot(v_temp, chi_square(v_chi_mrt2, v_chi_true, v_chi_mrt2_err)[1], 'o-', label='Susceptibility', color=colors[1])
plt.plot(v_temp, chi_square(v_te_mrt2, v_te_true, v_te_mrt2_err)[1], 'o-', label='Total Energy', color=colors[2])
plt.plot(v_temp, chi_square(v_cv_mrt2, v_cv_true, v_cv_mrt2_err)[1], 'o-', label='Specific Heat', color=colors[3])
plt.title('Metropolis', fontsize=15)
plt.ylabel('$Chi^2$')
plt.xlabel('Temperature')
plt.grid()
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(v_temp, chi_square(v_m_gibbs, v_m_true, v_m_gibbs_err)[1], 'o-', label='Magnetization', color=colors[4])
plt.plot(v_temp, chi_square(v_chi_gibbs, v_chi_true, v_chi_gibbs_err)[1], 'o-', label='Susceptibility', color=colors[5])
plt.plot(v_temp, chi_square(v_te_gibbs, v_te_true, v_te_gibbs_err)[1], 'o-', label='Total Energy', color=colors[6])
plt.plot(v_temp, chi_square(v_cv_gibbs, v_cv_true, v_cv_gibbs_err)[1], 'o-', label='Specific Heat', color=colors[7])
plt.grid()
plt.title('Gibbs', fontsize=15)
plt.ylabel('$Chi^2$')
plt.xlabel('Temperature')
plt.legend()

plt.show()
